# %%
import sys
import collections
import os
import time

import torch as th
from torch import nn
from torch.utils.data import DataLoader, Dataset
import geoopt as gt

import numpy as np

import dill
import yaml
from tqdm import tqdm

from probe.euclid import *
from probe.hyper import *
from util.data import custom_pad
from util.loss import *
from util.evalu import *
from util.train import *

# %%
default_dtype = th.float64
th.set_default_dtype(default_dtype)

device = th.device('cuda:0' if th.cuda.is_available() else 'cpu')

model_name = 'bert-base-cased'
layer_index = 7
data_dir = './data/dataset/'
dev_distance_dataset_path = os.path.join(data_dir, 
                                         'distance', 
                                         model_name, 
                                         'dev-layer-' + str(layer_index) + '.pt')
dev_dataset = th.load(dev_distance_dataset_path, pickle_module=dill)

# %% [markdown]
# ## Visualization

# %%
# %matplotlib inline

import random

import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics import mean_absolute_error

import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.offsetbox import AnchoredText
from matplotlib.path import Path
import matplotlib.patches as patches

from util.viz import *

plt.style.use('default')
plt.rcParams["font.family"] = "DejaVu Serif"
mpl.rcParams['figure.dpi'] = 100

stop_words = ',.:;?()``\"\'\''

# %%
config_file = os.path.join("./", "config", "example.yaml")
config_yaml = yaml.load(open(config_file), Loader=yaml.FullLoader)
probe_config = config_yaml['probe']
PROBE_OUT = probe_config["dim_out"]
probe = PoincareProbe(
            device=device,
            curvature=probe_config["c"],
            dim_in=probe_config["dim_in"],
            dim_out=probe_config["dim_out"],
            dim_hidden=probe_config["dim_hidden"],
            default_dtype=default_dtype,
        )
probe.to(device)
probe.load_state_dict(th.load('./checkpoint/syntax-poincare-probe.pt', 
    map_location=device))
# Out:
# Constructing PoincareProbe
# <All keys matched successfully>

# %%
batch_size = len(dev_dataset)
rand_inst_i = random.randint(0, batch_size)
viz, sentence, uuas, \
    root_acc, root_idx, root_depth, \
    gold_edges, pred_edges = \
    vizInstance(dev_dataset, rand_inst_i, probe)
length = len(sentence)
print(f"Instance: {rand_inst_i}")
print(' '.join(sentence))
print(f"Sentence length: {length}")
print(f"BERT_base_{layer_index} | Hyperbolic Dim: {viz.shape[1]}")
print(f"UUAS: {uuas:.4f} | Root Acc: {root_acc}, Depth: {root_depth:.4f}")
# Out:
# Instance: 930
# `` It was a pretty wild day .
# Sentence length: 8
# BERT_base_7 | Hyperbolic Dim: 64
# UUAS: 1.0000 | Root Acc: True, Depth: 0.3386

# %%
viz_pca = PCA(n_components=2).fit_transform(viz)
radius = round(abs(viz_pca).max(), 1) + 1e-1
fig, ax = plotPoincare(viz_pca, 
                       radius,
                       root_idx,
                       sentence,
                       gold_edges, 
                       pred_edges,
                       stop_words, 
                       geodesic=True)
at = AnchoredText(f"UUAS: {uuas:.2f}\n" + 
                  f"Root: {root_acc}\n" +
                  f"Root Depth: {root_depth:.2f}",
                  frameon=True,
                  loc='lower left',
                  prop=dict(fontsize="14"),
                  )
ax.add_artist(at)
fig.show()

# %% [markdown]
# ## Parse tree

# %%
sentence, loc_x, loc_depth, gold_edges =\
    vizParseTree(dev_dataset, rand_inst_i)
fig, ax = plotParseTree(sentence, loc_x, loc_depth, gold_edges, stop_words)
fig.show()
